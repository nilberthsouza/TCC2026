# %%
v_pu = "ola"

print(v_pu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 import py_dss_interface
#       6 import numpy as np
#       7
#       8 # Caminho
# ----> 9 script_path = os.path.dirname(os.path.abspath(__file__))
#      10 dss_file = pathlib.Path(script_path).joinpath("34Bus", "ieee34Mod1.dss")
#      11
#      12 dss = py_dss_interface.DSS()
#
# NameError: name '__file__' is not defined
